# %% [markdown]
# **Source:**
# [**Issue #2**](https://github.com/VinAIResearch/PhoNER_COVID19/issues/2) tại repo của dataset PhoNER_Covid19 (Do em hỏi)

# %% [markdown]
# # Preprocess

# %%
# %%capture
# !git clone https://github.com/VinAIResearch/PhoNER_COVID19.git
# !git clone https://github.com/quangdaist123/transformers.git
# !cd transformers/ && python3 -m pip install --no-cache-dir .
# !cd transformers/examples/legacy/token-classification

# %%
#Preprocessing
# !python /content/transformers/examples/legacy/token-classification/scripts/preprocess.py /content/PhoNER_COVID19/data/syllable/train_syllable.conll bert-base-multilingual-cased 128 > train.txt
# !python /content/transformers/examples/legacy/token-classification/scripts/preprocess.py /content/PhoNER_COVID19/data/syllable/dev_syllable.conll bert-base-multilingual-cased 128 > dev.txt
# !python /content/transformers/examples/legacy/token-classification/scripts/preprocess.py /content/PhoNER_COVID19/data/syllable/test_syllable.conll bert-base-multilingual-uncased 128 > test.txt
# !cat train.txt dev.txt test.txt | cut -d " " -f 2 | grep -v "^$"| sort | uniq > labels.txt

# %% [markdown]
# # Train

# %%
# !python /content/transformers/examples/legacy/token-classification/run_ner.py \
--task_type NER \
--overwrite_output_dir True \
--data_dir '/content/' \
--labels '/content/labels.txt' \
--model_name_or_path 'bert-base-multilingual-cased' \
--output_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=16' \
--learning_rate 5e-5 \
--weight_decay 0000 \
--max_seq_length  128 \
--num_train_epochs 30 \
--per_device_train_batch_size 16 \
--per_device_eval_batch_size 16 \
--save_total_limit=5 \
--seed 1 \
--do_train \
--do_eval \
--do_predict \
--logging_strategy epoch \
--evaluation_strategy epoch \
--save_strategy epoch \
--lr_scheduler_type 'constant' \
--metric_for_best_model 'eval_f1' \
--logging_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=16'  \
--load_best_model_at_end True \
# Out:
# 12/18/2021 10:47:55 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/18/2021 10:47:55 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=True,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
# !python /content/transformers/examples/legacy/token-classification/run_ner.py \
--task_type NER \
--overwrite_output_dir True \
--data_dir '/content/' \
--labels '/content/labels.txt' \
--model_name_or_path 'bert-base-multilingual-cased' \
--output_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=8' \
--learning_rate 5e-5 \
--weight_decay 0000 \
--max_seq_length  128 \
--num_train_epochs 30 \
--per_device_train_batch_size 8 \
--per_device_eval_batch_size 8 \
--save_total_limit=5 \
--seed 1 \
--do_train \
--do_eval \
--do_predict \
--logging_strategy epoch \
--evaluation_strategy epoch \
--save_strategy epoch \
--lr_scheduler_type 'constant' \
--metric_for_best_model 'eval_f1' \
--logging_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=8'  \
--load_best_model_at_end True \--load_best_model_at_end True \
# Out:
# 12/18/2021 11:15:37 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/18/2021 11:15:37 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=True,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
# !python /content/transformers/examples/legacy/token-classification/run_ner.py \
--task_type NER \
--overwrite_output_dir True \
--data_dir '/content/' \
--labels '/content/labels.txt' \
--model_name_or_path 'bert-base-multilingual-cased' \
--output_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=4' \
--learning_rate 5e-5 \
--num_train_epochs 30 \
--per_device_train_batch_size 4 \
--per_device_eval_batch_size 4 \
--save_total_limit=5 \
--seed 1 \
--do_train \
--do_eval \
--do_predict \
--logging_strategy epoch \
--evaluation_strategy epoch \
--save_strategy epoch \
--lr_scheduler_type 'constant' \
--metric_for_best_model 'eval_f1' \
--logging_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=4'  \
--load_best_model_at_end True \
# Out:
# 12/18/2021 12:08:16 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/18/2021 12:08:16 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=True,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
# !python /content/transformers/examples/legacy/token-classification/run_ner.py \
--task_type NER \
--overwrite_output_dir True \
--data_dir '/content/' \
--labels '/content/labels.txt' \
--model_name_or_path 'bert-base-multilingual-cased' \
--output_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=2' \
--learning_rate 5e-5 \
--weight_decay 0000 \
--max_seq_length  128 \
--num_train_epochs 30 \
--per_device_train_batch_size 2 \
--per_device_eval_batch_size 2 \
--save_total_limit=5 \
--seed 1 \
--do_train \
--do_eval \
--do_predict \
--logging_strategy epoch \
--evaluation_strategy epoch \
--save_strategy epoch \
--lr_scheduler_type 'constant' \
--metric_for_best_model 'eval_f1' \
--logging_dir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/bert-base-multilingual-cased/5e-5 batch_size=2'  \
--load_best_model_at_end True \
# Out:
# 12/18/2021 12:37:30 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/18/2021 12:37:30 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# bf16=False,
# bf16_full_eval=False,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=True,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ...

# %%
callbacks = [EarlyStoppingCallback(early_stopping_patience=5)]

# %% [markdown]
# # Visualize

# %%
# %reload_ext tensorboard
# %tensorboard --logdir '/content/drive/MyDrive/Môn học/NLP materials/Do an/test-ner/phobert-large'
